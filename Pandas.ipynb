# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelvalenciac/Ciencias_datos/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas

import pandas as pd

# 1. Series

serie = pd.Series([5,10,15,20,25,30,35,40], name="Múltiplos")
print(serie)
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# 4    25
# 5    30
# 6    35
# 7    40
# Name: Múltiplos, dtype: int64

# %%
# 2. DataFrame

data_f = pd.DataFrame({
    "nombre": ["Santiago", "Mariana", "Roberto", "Gabriela", "Jorge"],
    "edad": [20, 18, 32, 23, 26],
    "Altura": [1.82,1.69,1.74,1.80,1.57]
})

print(data_f)
# Out:
#      nombre  edad  Altura
# 0  Santiago    20    1.82
# 1   Mariana    18    1.69
# 2   Roberto    32    1.74
# 3  Gabriela    23    1.80
# 4     Jorge    26    1.57

# %%
# 2. Leer DataFrames

# data_f = pd.read_json("datos.json")

url_covid = "https://www.datos.gov.co/resource/gt2j-8ykr.json"
dataf_covid = pd.read_json(url_covid)

dataf_covid.head()
# Out:
#      fecha_reporte_web  id_de_caso fecha_de_notificaci_n  departamento  \
# 0  2020-12-24 00:00:00     1556979   2020-12-22 00:00:00            76
# 1  2020-12-24 00:00:00     1556980   2020-12-19 00:00:00            76
# 2  2020-12-24 00:00:00     1556981   2020-12-19 00:00:00            76
# 3  2020-12-24 00:00:00     1556982   2020-12-22 00:00:00            76
# 4  2020-12-24 00:00:00     1556983   2020-12-22 00:00:00            76
#
#   departamento_nom  ciudad_municipio ciudad_municipio_nom  edad  \
# 0            VALLE             76001                 CALI    67
# 1            VALLE             76001                 CALI    66
# 2            VALLE             76001                 CALI    68
# 3            VALLE             76001                 CALI    74
# 4            VALLE             76001                 CALI    65
#
#    unidad_medida sexo  ...  ubicacion     estado  recuperado  \
# 0              1    F  ...       Casa       Leve  Recuperado
# ...

# %%
# 3. Exploración de un DataFrame

# Cabeza del DataFrame
#dataf_covid.head()

# Cola del DataFrame
#dataf_covid.tail()

# Información general
#dataf_covid.info()

# Estadística descriptiva
#dataf_covid.describe()

# Slicing
#dataf_covid.shape

# Columnas
#dataf_covid.columns

# %%
# 3. Selección de datos

#dataf_covid["id_de_caso"]
dataf_covid[["id_de_caso", "edad"]]
# Out:
#      id_de_caso  edad
# 0       1556979    67
# 1       1556980    66
# 2       1556981    68
# 3       1556982    74
# 4       1556983    65
# ..          ...   ...
# 995      640273    37
# 996      640274    12
# 997      640275    11
# 998      640276     6
# 999      640277    31
#
# [1000 rows x 2 columns]

# %%
# 4. Selección de datos

dataf_covid.iloc[327]
# Out:
# fecha_reporte_web        2020-07-25 00:00:00
# id_de_caso                            238787
# fecha_de_notificaci_n    2020-07-16 00:00:00
# departamento                              11
# departamento_nom                      BOGOTA
# ciudad_municipio                       11001
# ciudad_municipio_nom                  BOGOTA
# edad                                      68
# unidad_medida                              1
# sexo                                       F
# fuente_tipo_contagio             Relacionado
# ubicacion                               Casa
# estado                                  Leve
# recuperado                        Recuperado
# fecha_inicio_sintomas    2020-07-11 00:00:00
# fecha_diagnostico        2020-07-24 00:00:00
# fecha_recuperado         2020-08-09 00:00:00
# tipo_recuperacion                     Tiempo
# per_etn_                                   6
# fecha_muerte                             NaN
# nom_grupo_                               NaN
# ...

# %%
# 5. Filtros

# dataf_covid[dataf_covid["id_de_caso"] > 489]
# dataf_covid[(dataf_covid["id_de_caso"] > 683) & (dataf_covid["departamento_nom"] == "VALLE")]
# dataf_covid[(dataf_covid["id_de_caso"] > 927) | (dataf_covid["departamento_nom"] == "VALLE")]
dataf_covid[(dataf_covid["id_de_caso"] > 327) | ~(dataf_covid["departamento_nom"] == "VALLE")]
# Out:
#        fecha_reporte_web  id_de_caso fecha_de_notificaci_n  departamento  \
# 0    2020-12-24 00:00:00     1556979   2020-12-22 00:00:00            76
# 1    2020-12-24 00:00:00     1556980   2020-12-19 00:00:00            76
# 2    2020-12-24 00:00:00     1556981   2020-12-19 00:00:00            76
# 3    2020-12-24 00:00:00     1556982   2020-12-22 00:00:00            76
# 4    2020-12-24 00:00:00     1556983   2020-12-22 00:00:00            76
# ..                   ...         ...                   ...           ...
# 995  2020-09-03 00:00:00      640273   2020-08-11 00:00:00             5
# 996  2020-09-03 00:00:00      640274   2020-08-13 00:00:00            68
# 997  2020-09-03 00:00:00      640275   2020-08-13 00:00:00            68
# 998  2020-09-03 00:00:00      640276   2020-08-13 00:00:00            68
# 999  2020-09-03 00:00:00      640277   2020-08-14 00:00:00             5
#
#     departamento_nom  ciudad_municipio ciudad_municipio_nom  edad  \
# ...

# %%
# 6. Operaciones de columnas

dataf_covid["edad2"] = dataf_covid["edad"] * 2
print(dataf_covid["edad2"])
# Out:
# 0      134
# 1      132
# 2      136
# 3      148
# 4      130
#       ...
# 995     74
# 996     24
# 997     22
# 998     12
# 999     62
# Name: edad2, Length: 1000, dtype: int64

# %%
# 8. Ordenar datos

dataf_covid.sort_values("edad")
# Out:
#        fecha_reporte_web  id_de_caso fecha_de_notificaci_n  departamento  \
# 598  2020-07-18 00:00:00      187658   2020-07-01 00:00:00            44
# 699  2020-10-23 00:00:00      993945   2020-10-21 00:00:00             5
# 305  2021-09-10 00:00:00     4926214   2021-09-03 00:00:00            76
# 701  2020-10-23 00:00:00      993947   2020-10-20 00:00:00             5
# 846  2020-06-25 00:00:00       78521   2020-06-21 00:00:00             5
# ..                   ...         ...                   ...           ...
# 903  2021-01-07 00:00:00     1734648   2021-01-03 00:00:00            76
# 901  2021-01-07 00:00:00     1734646   2020-12-31 00:00:00            76
# 780  2020-06-25 00:00:00       78535   2020-06-24 00:00:00             5
# 951  2021-01-07 00:00:00     1734616   2021-01-05 00:00:00            76
# 304  2020-07-25 00:00:00      238807   2020-07-20 00:00:00            11
#
#     departamento_nom  ciudad_municipio ciudad_municipio_nom  edad  \
# ...
